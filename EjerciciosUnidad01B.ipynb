# %% [raw]
# ---
# title: "[Tarea 03] Ejercicios Unidad 01-B"
# author: "Richard Tipantiza"
# lang: es
# format:
#   pdf:
#     toc: true
#     toc-title: "Tabla de Contenidos"
# execute:
#   echo: true
#   error: false
#   warning: false
# jupyter: python3
# ---
